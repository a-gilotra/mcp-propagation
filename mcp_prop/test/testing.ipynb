# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
p = np.loadtxt('/Users/ayushg/Documents/GitHub/millisim_copy/p_array.txt')
print(np.shape(p))
# Out:
# (693, 3)

# %%
x = p[:, 0]
y = p[:, 1]
z = p[:, 2]
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for i in range(25):
    ax.quiver(0, 0, 0, p[i, 0], p[i, 1], p[i, 2], color='b', pivot='tail')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.view_init(elev=30, azim=30)
plt.show()
